# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

# %%
df_balance = pd.read_csv('fish_data.csv')

# %%
df_balance
# Out:
#                     species  length  weight  w_l_ratio
# 0        Anabas testudineus   10.66    3.45       0.32
# 1        Anabas testudineus    6.91    3.27       0.47
# 2        Anabas testudineus    8.38    3.46       0.41
# 3        Anabas testudineus    7.57    3.36       0.44
# 4        Anabas testudineus   10.83    3.38       0.31
# ...                     ...     ...     ...        ...
# 4075  Sillaginopsis panijus   30.56    6.12       0.20
# 4076  Sillaginopsis panijus   29.66    6.11       0.21
# 4077  Sillaginopsis panijus   32.81    6.25       0.19
# 4078  Sillaginopsis panijus   29.78    6.11       0.21
# 4079  Sillaginopsis panijus   31.62    6.14       0.19
#
# [4080 rows x 4 columns]

# %%
df_balance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4080 entries, 0 to 4079
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   species    4080 non-null   object
#  1   length     4080 non-null   float64
#  2   weight     4080 non-null   float64
#  3   w_l_ratio  4080 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 127.6+ KB

# %%
pd.unique(df_balance['species'])
# Out:
# array(['Anabas testudineus', 'Coilia dussumieri',
#        'Otolithoides biauritus', 'Otolithoides pama', 'Pethia conchonius',
#        'Polynemus paradiseus', 'Puntius lateristriga', 'Setipinna taty',
#        'Sillaginopsis panijus'], dtype=object)

# %%
pd.unique(df_balance['species'].value_counts())
# Out:
# array([480, 476, 475, 468, 458, 455, 435, 418, 415], dtype=int64)

# %%
x = df_balance.iloc[:,1:].values
y = df_balance.iloc[:,[0]].values

# %%
y = y.reshape(len (y),)

# %%
#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#x = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
svm_model = SVC(kernel='linear', random_state=0)
svm_model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = svm_model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9154411764705882
# Classification Report:
#                          precision    recall  f1-score   support
#
#     Anabas testudineus       1.00      1.00      1.00        97
#      Coilia dussumieri       1.00      1.00      1.00        96
# Otolithoides biauritus       0.67      0.60      0.63       100
#      Otolithoides pama       1.00      1.00      1.00        85
#      Pethia conchonius       1.00      1.00      1.00        84
#   Polynemus paradiseus       1.00      1.00      1.00        85
#   Puntius lateristriga       1.00      1.00      1.00        74
#         Setipinna taty       0.65      0.72      0.68       103
#  Sillaginopsis panijus       1.00      1.00      1.00        92
#
#               accuracy                           0.92       816
#              macro avg       0.92      0.92      0.92       816
#           weighted avg       0.92      0.92      0.92       816

# %% [markdown]
# ### kernel terbaik

# %%
# List kernel yang akan diuji
kernels = ['linear', 'rbf', 'poly',  'sigmoid']
kernel_results = {}

# Loop melalui setiap kernel
for kernel in kernels:
    # Buat model dengan kernel tertentu
    svm = SVC(kernel=kernel, random_state=0)
    svm.fit(x_train, y_train)  # Latih model
    
    # Prediksi dan evaluasi
    y_pred = svm.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    
    # Simpan hasil
    kernel_results[kernel] = acc

# Cetak hasil untuk setiap kernel
for k, v in kernel_results.items():
    print(f"Kernel: {k}, Accuracy: {v}")

# Cari kernel terbaik
best_kernel = max(kernel_results, key=kernel_results.get)
print(f"Kernel terbaik: {best_kernel}")
# Out:
# Kernel: linear, Accuracy: 0.9154411764705882
# Kernel: rbf, Accuracy: 0.8627450980392157
# Kernel: poly, Accuracy: 0.8737745098039216
# Kernel: sigmoid, Accuracy: 0.012254901960784314
# Kernel terbaik: linear

# %%
new_data = [[30.56,6.12,0.20]]
#scaled_data = scaler.transform(new_data)
new_pred = svm_model.predict(new_data)
print(new_pred)
# Out:
# ['Sillaginopsis panijus']
